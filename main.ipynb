# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import regex as re
import os
import torch
from datasets import Dataset
from sklearn.model_selection import *
np.bool = bool
import torch.nn as nn
import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch.nn.functional as F
# import regex as re
# from datasets import load_dataset, Dataset, DatasetDict
# import torch.optim as optim
# from torch.utils.data import Dataset, DataLoader
# import wandb


print(torch.cuda.is_available())

data = pd.read_parquet("merged.pq")
data
# Out:
# True
#                                                lecture  \
# 0    Watch a video about Evolution by Natural Selec...
# 1    Watch a video about the Scientific Method. Fig...
# 2    Watch a video about electrons and how the elec...
# 3    Watch a video about why we need oxygen and how...
# 4    Watch a video about proteins and protein enzym...
# ..                                                 ...
# 801  Types of Higher Education Programs Today’s stu...
# 802  How to Grow Tomatoes from a Seedling Growing t...
# 803  Defining Good Students Means More than Just Gr...
# 804  Comparing and Contrasting London and Washingto...
# 805  Effects of Video Game Addiction Video game add...
#
#                                         question_group
# 0    Identify and describe the properties of life\n...
# 1    Identify the shared characteristics of the nat...
# 2    Describe matter and elements\nDescribe the int...
# 3    Describe the properties of water that are crit...
# 4    Describe the ways in which carbon is critical ...
# ..                                                 ...
# 801  Read an example of the classification rhetoric...
# 802  Read an example of the process analysis rhetor...
# 803  Read an example of the definition rhetorical mode
# 804  Read an example of the compare and contrast rh...
# 805  Read an example of the cause and effect rhetor...
#
# [806 rows x 2 columns]

# %%
train_df, val_df = train_test_split(data, test_size=0.2, random_state=42)
# train_df = train_df[:10]
# val_df = val_df[:10]

# %%
model_name="microsoft/phi-1_5"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.add_special_tokens({'pad_token': '[PAD]'})

def create_dataset(df):
    data_dict = {
        'input_ids': [],
        'attention_mask': [],
        'labels': []
    }

    for _, row in df.iterrows():
        lecture = row['lecture']
        question_group = row['question_group']

        # Tokenizing a prompt without the lecture to determine its size
        prompt_without_lecture = "###Lecture:\n\n" + " " + "\n\n###Learning Objectives:\n\n" + question_group
        prompt_without_lecture_length = len(tokenizer.tokenize(prompt_without_lecture))
        max_lecture_length = 2048 - prompt_without_lecture_length

        # Truncate the lecture
        avg_token_size = 3
        max_lecture_characters = (max_lecture_length * avg_token_size) 
        truncated_lecture = lecture[:max_lecture_characters]

        # Tokenize
        prompt = "###Lecture:\n\n" + truncated_lecture + "\n\n###Learning Objectives:\n\n" + question_group
        tokens = tokenizer(prompt, truncation=True, max_length=2048, padding='max_length', return_tensors='pt')

        input_ids = tokens['input_ids'].squeeze().tolist()
        attention_mask = tokens['attention_mask'].squeeze().tolist()

        # Labeling: -100 for all tokens except those in question_group
        labels = -100 * torch.ones_like(tokens['input_ids']).squeeze()
        question_tokens = tokenizer.encode(question_group, add_special_tokens=False)
        idx_start_positions = (tokens['input_ids'].squeeze() == question_tokens[0]).nonzero().squeeze()

        # Check if any starting positions were found
        if idx_start_positions.numel() == 0:  # No positions found
            continue
        elif len(idx_start_positions.size()) == 0:  # Only one position found
            idx_start = idx_start_positions.item()
        else:  # Multiple positions found
            idx_start = idx_start_positions[0].item()
        
        labels[idx_start:idx_start+len(question_tokens)] = tokens['input_ids'].squeeze()[idx_start:idx_start+len(question_tokens)]
        labels = labels.tolist()

        data_dict['input_ids'].append(input_ids)
        data_dict['attention_mask'].append(attention_mask)
        data_dict['labels'].append(labels)

    return Dataset.from_dict(data_dict)




train_dataset = create_dataset(train_df)
val_dataset = create_dataset(val_df)

# %%
def get_trainable_params(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )

# %%
example = train_dataset.__getitem__(1)
for i in range(2048):
    print("token_id:", example['input_ids'][i], "|| attention_mask:", example['attention_mask'][i], "|| label:", example['labels'][i], "original text:", tokenizer.decode(example['input_ids'][i]))
# Out:
# token_id: 21017 || attention_mask: 1 || label: -100 original text: ###
# token_id: 43 || attention_mask: 1 || label: -100 original text: L
# token_id: 478 || attention_mask: 1 || label: -100 original text: ect
# token_id: 495 || attention_mask: 1 || label: -100 original text: ure
# token_id: 25 || attention_mask: 1 || label: -100 original text: :
# token_id: 198 || attention_mask: 1 || label: -100 original text:
#
# token_id: 198 || attention_mask: 1 || label: -100 original text:
#
# token_id: 464 || attention_mask: 1 || label: -100 original text: The
# token_id: 26632 || attention_mask: 1 || label: -100 original text:  Elements
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 3611 || attention_mask: 1 || label: -100 original text:  General
# token_id: 9344 || attention_mask: 1 || label: -100 original text:  Environment
# token_id: 25 || attention_mask: 1 || label: -100 original text: :
# token_id: 350 || attention_mask: 1 || label: -100 original text:  P
# token_id: 6465 || attention_mask: 1 || label: -100 original text: EST
# token_id: 3698 || attention_mask: 1 || label: -100 original text: EL
# token_id: 14691 || attention_mask: 1 || label: -100 original text:  Analysis
# token_id: 1052 || attention_mask: 1 || label: -100 original text:  An
# token_id: 4009 || attention_mask: 1 || label: -100 original text:  organization
# token_id: 447 || attention_mask: 1 || label: -100 original text: �
# token_id: 247 || attention_mask: 1 || label: -100 original text: �
# token_id: 82 || attention_mask: 1 || label: -100 original text: s
# token_id: 2858 || attention_mask: 1 || label: -100 original text:  environment
# token_id: 3407 || attention_mask: 1 || label: -100 original text:  includes
# token_id: 5087 || attention_mask: 1 || label: -100 original text:  factors
# token_id: 326 || attention_mask: 1 || label: -100 original text:  that
# token_id: 340 || attention_mask: 1 || label: -100 original text:  it
# token_id: 460 || attention_mask: 1 || label: -100 original text:  can
# token_id: 14704 || attention_mask: 1 || label: -100 original text:  readily
# token_id: 2689 || attention_mask: 1 || label: -100 original text:  affect
# token_id: 355 || attention_mask: 1 || label: -100 original text:  as
# token_id: 880 || attention_mask: 1 || label: -100 original text:  well
# token_id: 355 || attention_mask: 1 || label: -100 original text:  as
# token_id: 5087 || attention_mask: 1 || label: -100 original text:  factors
# token_id: 326 || attention_mask: 1 || label: -100 original text:  that
# token_id: 5688 || attention_mask: 1 || label: -100 original text:  largely
# token_id: 3830 || attention_mask: 1 || label: -100 original text:  lay
# token_id: 3675 || attention_mask: 1 || label: -100 original text:  beyond
# token_id: 663 || attention_mask: 1 || label: -100 original text:  its
# token_id: 4588 || attention_mask: 1 || label: -100 original text:  influence
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 383 || attention_mask: 1 || label: -100 original text:  The
# token_id: 6846 || attention_mask: 1 || label: -100 original text:  latter
# token_id: 900 || attention_mask: 1 || label: -100 original text:  set
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 5087 || attention_mask: 1 || label: -100 original text:  factors
# token_id: 389 || attention_mask: 1 || label: -100 original text:  are
# token_id: 531 || attention_mask: 1 || label: -100 original text:  said
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 2152 || attention_mask: 1 || label: -100 original text:  exist
# token_id: 1626 || attention_mask: 1 || label: -100 original text:  within
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 2276 || attention_mask: 1 || label: -100 original text:  general
# token_id: 2858 || attention_mask: 1 || label: -100 original text:  environment
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 4362 || attention_mask: 1 || label: -100 original text:  Because
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 2276 || attention_mask: 1 || label: -100 original text:  general
# token_id: 2858 || attention_mask: 1 || label: -100 original text:  environment
# token_id: 1690 || attention_mask: 1 || label: -100 original text:  often
# token_id: 468 || attention_mask: 1 || label: -100 original text:  has
# token_id: 257 || attention_mask: 1 || label: -100 original text:  a
# token_id: 8904 || attention_mask: 1 || label: -100 original text:  substantial
# token_id: 4588 || attention_mask: 1 || label: -100 original text:  influence
# token_id: 319 || attention_mask: 1 || label: -100 original text:  on
# token_id: 281 || attention_mask: 1 || label: -100 original text:  an
# token_id: 4009 || attention_mask: 1 || label: -100 original text:  organization
# token_id: 447 || attention_mask: 1 || label: -100 original text: �
# token_id: 247 || attention_mask: 1 || label: -100 original text: �
# token_id: 82 || attention_mask: 1 || label: -100 original text: s
# token_id: 1241 || attention_mask: 1 || label: -100 original text:  level
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 1943 || attention_mask: 1 || label: -100 original text:  success
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 12353 || attention_mask: 1 || label: -100 original text:  executives
# token_id: 1276 || attention_mask: 1 || label: -100 original text:  must
# token_id: 2610 || attention_mask: 1 || label: -100 original text:  track
# token_id: 11257 || attention_mask: 1 || label: -100 original text:  trends
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 2995 || attention_mask: 1 || label: -100 original text:  events
# token_id: 355 || attention_mask: 1 || label: -100 original text:  as
# token_id: 484 || attention_mask: 1 || label: -100 original text:  they
# token_id: 18101 || attention_mask: 1 || label: -100 original text:  evolve
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 1949 || attention_mask: 1 || label: -100 original text:  try
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 23794 || attention_mask: 1 || label: -100 original text:  anticipate
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 10939 || attention_mask: 1 || label: -100 original text:  implications
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 777 || attention_mask: 1 || label: -100 original text:  these
# token_id: 11257 || attention_mask: 1 || label: -100 original text:  trends
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 2995 || attention_mask: 1 || label: -100 original text:  events
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 350 || attention_mask: 1 || label: -100 original text:  P
# token_id: 6465 || attention_mask: 1 || label: -100 original text: EST
# token_id: 3698 || attention_mask: 1 || label: -100 original text: EL
# token_id: 3781 || attention_mask: 1 || label: -100 original text:  analysis
# token_id: 318 || attention_mask: 1 || label: -100 original text:  is
# token_id: 530 || attention_mask: 1 || label: -100 original text:  one
# token_id: 1593 || attention_mask: 1 || label: -100 original text:  important
# token_id: 2891 || attention_mask: 1 || label: -100 original text:  tool
# token_id: 326 || attention_mask: 1 || label: -100 original text:  that
# token_id: 12353 || attention_mask: 1 || label: -100 original text:  executives
# token_id: 460 || attention_mask: 1 || label: -100 original text:  can
# token_id: 8814 || attention_mask: 1 || label: -100 original text:  rely
# token_id: 319 || attention_mask: 1 || label: -100 original text:  on
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 16481 || attention_mask: 1 || label: -100 original text:  organize
# token_id: 5087 || attention_mask: 1 || label: -100 original text:  factors
# token_id: 1626 || attention_mask: 1 || label: -100 original text:  within
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 2276 || attention_mask: 1 || label: -100 original text:  general
# token_id: 2858 || attention_mask: 1 || label: -100 original text:  environment
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 5911 || attention_mask: 1 || label: -100 original text:  identify
# token_id: 703 || attention_mask: 1 || label: -100 original text:  how
# token_id: 777 || attention_mask: 1 || label: -100 original text:  these
# token_id: 5087 || attention_mask: 1 || label: -100 original text:  factors
# token_id: 4588 || attention_mask: 1 || label: -100 original text:  influence
# token_id: 11798 || attention_mask: 1 || label: -100 original text:  industries
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 9611 || attention_mask: 1 || label: -100 original text:  firms
# token_id: 1626 || attention_mask: 1 || label: -100 original text:  within
# token_id: 606 || attention_mask: 1 || label: -100 original text:  them
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 350 || attention_mask: 1 || label: -100 original text:  P
# token_id: 6465 || attention_mask: 1 || label: -100 original text: EST
# token_id: 3698 || attention_mask: 1 || label: -100 original text: EL
# token_id: 318 || attention_mask: 1 || label: -100 original text:  is
# token_id: 281 || attention_mask: 1 || label: -100 original text:  an
# token_id: 281 || attention_mask: 1 || label: -100 original text:  an
# token_id: 6713 || attention_mask: 1 || label: -100 original text: agram
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 3616 || attention_mask: 1 || label: -100 original text:  meaning
# token_id: 340 || attention_mask: 1 || label: -100 original text:  it
# token_id: 318 || attention_mask: 1 || label: -100 original text:  is
# token_id: 257 || attention_mask: 1 || label: -100 original text:  a
# token_id: 1573 || attention_mask: 1 || label: -100 original text:  word
# token_id: 326 || attention_mask: 1 || label: -100 original text:  that
# token_id: 2727 || attention_mask: 1 || label: -100 original text:  created
# token_id: 416 || attention_mask: 1 || label: -100 original text:  by
# token_id: 1262 || attention_mask: 1 || label: -100 original text:  using
# token_id: 3354 || attention_mask: 1 || label: -100 original text:  parts
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 584 || attention_mask: 1 || label: -100 original text:  other
# token_id: 2456 || attention_mask: 1 || label: -100 original text:  words
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 554 || attention_mask: 1 || label: -100 original text:  In
# token_id: 1948 || attention_mask: 1 || label: -100 original text:  particular
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 350 || attention_mask: 1 || label: -100 original text:  P
# token_id: 6465 || attention_mask: 1 || label: -100 original text: EST
# token_id: 3698 || attention_mask: 1 || label: -100 original text: EL
# token_id: 12497 || attention_mask: 1 || label: -100 original text:  reflects
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 3891 || attention_mask: 1 || label: -100 original text:  names
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 2237 || attention_mask: 1 || label: -100 original text:  six
# token_id: 17894 || attention_mask: 1 || label: -100 original text:  segments
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 2276 || attention_mask: 1 || label: -100 original text:  general
# token_id: 2858 || attention_mask: 1 || label: -100 original text:  environment
# token_id: 25 || attention_mask: 1 || label: -100 original text: :
# token_id: 357 || attention_mask: 1 || label: -100 original text:  (
# token_id: 16 || attention_mask: 1 || label: -100 original text: 1
# token_id: 8 || attention_mask: 1 || label: -100 original text: )
# token_id: 1964 || attention_mask: 1 || label: -100 original text:  political
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 357 || attention_mask: 1 || label: -100 original text:  (
# token_id: 17 || attention_mask: 1 || label: -100 original text: 2
# token_id: 8 || attention_mask: 1 || label: -100 original text: )
# token_id: 3034 || attention_mask: 1 || label: -100 original text:  economic
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 357 || attention_mask: 1 || label: -100 original text:  (
# token_id: 18 || attention_mask: 1 || label: -100 original text: 3
# token_id: 8 || attention_mask: 1 || label: -100 original text: )
# token_id: 1919 || attention_mask: 1 || label: -100 original text:  social
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 357 || attention_mask: 1 || label: -100 original text:  (
# token_id: 19 || attention_mask: 1 || label: -100 original text: 4
# token_id: 8 || attention_mask: 1 || label: -100 original text: )
# token_id: 14614 || attention_mask: 1 || label: -100 original text:  technological
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 357 || attention_mask: 1 || label: -100 original text:  (
# token_id: 20 || attention_mask: 1 || label: -100 original text: 5
# token_id: 8 || attention_mask: 1 || label: -100 original text: )
# token_id: 6142 || attention_mask: 1 || label: -100 original text:  environmental
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 357 || attention_mask: 1 || label: -100 original text:  (
# token_id: 21 || attention_mask: 1 || label: -100 original text: 6
# token_id: 8 || attention_mask: 1 || label: -100 original text: )
# token_id: 2742 || attention_mask: 1 || label: -100 original text:  legal
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 28908 || attention_mask: 1 || label: -100 original text:  Wise
# token_id: 12353 || attention_mask: 1 || label: -100 original text:  executives
# token_id: 7773 || attention_mask: 1 || label: -100 original text:  carefully
# token_id: 10716 || attention_mask: 1 || label: -100 original text:  examine
# token_id: 1123 || attention_mask: 1 || label: -100 original text:  each
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 777 || attention_mask: 1 || label: -100 original text:  these
# token_id: 2237 || attention_mask: 1 || label: -100 original text:  six
# token_id: 17894 || attention_mask: 1 || label: -100 original text:  segments
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 5911 || attention_mask: 1 || label: -100 original text:  identify
# token_id: 1688 || attention_mask: 1 || label: -100 original text:  major
# token_id: 6443 || attention_mask: 1 || label: -100 original text:  opportunities
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 7432 || attention_mask: 1 || label: -100 original text:  threats
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 788 || attention_mask: 1 || label: -100 original text:  then
# token_id: 4532 || attention_mask: 1 || label: -100 original text:  adjust
# token_id: 511 || attention_mask: 1 || label: -100 original text:  their
# token_id: 9611 || attention_mask: 1 || label: -100 original text:  firms
# token_id: 447 || attention_mask: 1 || label: -100 original text: �
# token_id: 247 || attention_mask: 1 || label: -100 original text: �
# token_id: 10064 || attention_mask: 1 || label: -100 original text:  strategies
# token_id: 16062 || attention_mask: 1 || label: -100 original text:  accordingly
# token_id: 357 || attention_mask: 1 || label: -100 original text:  (
# token_id: 11291 || attention_mask: 1 || label: -100 original text:  Figure
# token_id: 513 || attention_mask: 1 || label: -100 original text:  3
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 18 || attention_mask: 1 || label: -100 original text: 3
# token_id: 564 || attention_mask: 1 || label: -100 original text:  �
# token_id: 250 || attention_mask: 1 || label: -100 original text: �
# token_id: 47 || attention_mask: 1 || label: -100 original text: P
# token_id: 6465 || attention_mask: 1 || label: -100 original text: EST
# token_id: 3698 || attention_mask: 1 || label: -100 original text: EL
# token_id: 447 || attention_mask: 1 || label: -100 original text: �
# token_id: 251 || attention_mask: 1 || label: -100 original text: �
# token_id: 6739 || attention_mask: 1 || label: -100 original text:  ).
# token_id: 11291 || attention_mask: 1 || label: -100 original text:  Figure
# token_id: 513 || attention_mask: 1 || label: -100 original text:  3
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 18 || attention_mask: 1 || label: -100 original text: 3
# token_id: 25 || attention_mask: 1 || label: -100 original text: :
# token_id: 350 || attention_mask: 1 || label: -100 original text:  P
# token_id: 6465 || attention_mask: 1 || label: -100 original text: EST
# token_id: 3698 || attention_mask: 1 || label: -100 original text: EL
# token_id: 685 || attention_mask: 1 || label: -100 original text:  [
# token_id: 5159 || attention_mask: 1 || label: -100 original text: Image
# token_id: 6764 || attention_mask: 1 || label: -100 original text:  description
# token_id: 60 || attention_mask: 1 || label: -100 original text: ]
# token_id: 350 || attention_mask: 1 || label: -100 original text:  P
# token_id: 1148 || attention_mask: 1 || label: -100 original text:  Is
# token_id: 329 || attention_mask: 1 || label: -100 original text:  for
# token_id: 564 || attention_mask: 1 || label: -100 original text:  �
# token_id: 250 || attention_mask: 1 || label: -100 original text: �
# token_id: 35443 || attention_mask: 1 || label: -100 original text: Political
# token_id: 447 || attention_mask: 1 || label: -100 original text: �
# token_id: 251 || attention_mask: 1 || label: -100 original text: �
# token_id: 383 || attention_mask: 1 || label: -100 original text:  The
# token_id: 1964 || attention_mask: 1 || label: -100 original text:  political
# token_id: 10618 || attention_mask: 1 || label: -100 original text:  segment
# token_id: 10399 || attention_mask: 1 || label: -100 original text:  centers
# token_id: 319 || attention_mask: 1 || label: -100 original text:  on
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 2597 || attention_mask: 1 || label: -100 original text:  role
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 6905 || attention_mask: 1 || label: -100 original text:  governments
# token_id: 287 || attention_mask: 1 || label: -100 original text:  in
# token_id: 23610 || attention_mask: 1 || label: -100 original text:  shaping
# token_id: 1597 || attention_mask: 1 || label: -100 original text:  business
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 770 || attention_mask: 1 || label: -100 original text:  This
# token_id: 10618 || attention_mask: 1 || label: -100 original text:  segment
# token_id: 3407 || attention_mask: 1 || label: -100 original text:  includes
# token_id: 4847 || attention_mask: 1 || label: -100 original text:  elements
# token_id: 884 || attention_mask: 1 || label: -100 original text:  such
# token_id: 355 || attention_mask: 1 || label: -100 original text:  as
# token_id: 1687 || attention_mask: 1 || label: -100 original text:  tax
# token_id: 4788 || attention_mask: 1 || label: -100 original text:  policies
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 2458 || attention_mask: 1 || label: -100 original text:  changes
# token_id: 287 || attention_mask: 1 || label: -100 original text:  in
# token_id: 3292 || attention_mask: 1 || label: -100 original text:  trade
# token_id: 8733 || attention_mask: 1 || label: -100 original text:  restrictions
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 29240 || attention_mask: 1 || label: -100 original text:  tariffs
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 10159 || attention_mask: 1 || label: -100 original text:  stability
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 6905 || attention_mask: 1 || label: -100 original text:  governments
# token_id: 357 || attention_mask: 1 || label: -100 original text:  (
# token_id: 11291 || attention_mask: 1 || label: -100 original text:  Figure
# token_id: 513 || attention_mask: 1 || label: -100 original text:  3
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 19 || attention_mask: 1 || label: -100 original text: 4
# token_id: 564 || attention_mask: 1 || label: -100 original text:  �
# token_id: 250 || attention_mask: 1 || label: -100 original text: �
# token_id: 35443 || attention_mask: 1 || label: -100 original text: Political
# token_id: 41140 || attention_mask: 1 || label: -100 original text:  Factors
# token_id: 447 || attention_mask: 1 || label: -100 original text: �
# token_id: 251 || attention_mask: 1 || label: -100 original text: �
# token_id: 6739 || attention_mask: 1 || label: -100 original text:  ).
# token_id: 18204 || attention_mask: 1 || label: -100 original text:  Immigration
# token_id: 2450 || attention_mask: 1 || label: -100 original text:  policy
# token_id: 318 || attention_mask: 1 || label: -100 original text:  is
# token_id: 281 || attention_mask: 1 || label: -100 original text:  an
# token_id: 4843 || attention_mask: 1 || label: -100 original text:  aspect
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 1964 || attention_mask: 1 || label: -100 original text:  political
# token_id: 10618 || attention_mask: 1 || label: -100 original text:  segment
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 2276 || attention_mask: 1 || label: -100 original text:  general
# token_id: 2858 || attention_mask: 1 || label: -100 original text:  environment
# token_id: 326 || attention_mask: 1 || label: -100 original text:  that
# token_id: 4394 || attention_mask: 1 || label: -100 original text:  offers
# token_id: 1593 || attention_mask: 1 || label: -100 original text:  important
# token_id: 10939 || attention_mask: 1 || label: -100 original text:  implications
# token_id: 329 || attention_mask: 1 || label: -100 original text:  for
# token_id: 867 || attention_mask: 1 || label: -100 original text:  many
# token_id: 1180 || attention_mask: 1 || label: -100 original text:  different
# token_id: 5745 || attention_mask: 1 || label: -100 original text:  organizations
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 1867 || attention_mask: 1 || label: -100 original text:  What
# token_id: 3164 || attention_mask: 1 || label: -100 original text:  approach
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 1011 || attention_mask: 1 || label: -100 original text:  take
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 5293 || attention_mask: 1 || label: -100 original text:  illegal
# token_id: 6272 || attention_mask: 1 || label: -100 original text:  immigration
# token_id: 656 || attention_mask: 1 || label: -100 original text:  into
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 1578 || attention_mask: 1 || label: -100 original text:  United
# token_id: 1829 || attention_mask: 1 || label: -100 original text:  States
# token_id: 422 || attention_mask: 1 || label: -100 original text:  from
# token_id: 5828 || attention_mask: 1 || label: -100 original text:  Mexico
# token_id: 468 || attention_mask: 1 || label: -100 original text:  has
# token_id: 587 || attention_mask: 1 || label: -100 original text:  been
# token_id: 257 || attention_mask: 1 || label: -100 original text:  a
# token_id: 50180 || attention_mask: 1 || label: -100 original text:  hotly
# token_id: 24594 || attention_mask: 1 || label: -100 original text:  debated
# token_id: 26566 || attention_mask: 1 || label: -100 original text:  dilemma
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 2773 || attention_mask: 1 || label: -100 original text:  Some
# token_id: 4436 || attention_mask: 1 || label: -100 original text:  hospital
# token_id: 12353 || attention_mask: 1 || label: -100 original text:  executives
# token_id: 423 || attention_mask: 1 || label: -100 original text:  have
# token_id: 4367 || attention_mask: 1 || label: -100 original text:  noted
# token_id: 326 || attention_mask: 1 || label: -100 original text:  that
# token_id: 5293 || attention_mask: 1 || label: -100 original text:  illegal
# token_id: 7971 || attention_mask: 1 || label: -100 original text:  immigrants
# token_id: 1234 || attention_mask: 1 || label: -100 original text:  put
# token_id: 257 || attention_mask: 1 || label: -100 original text:  a
# token_id: 14022 || attention_mask: 1 || label: -100 original text:  strain
# token_id: 319 || attention_mask: 1 || label: -100 original text:  on
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 1535 || attention_mask: 1 || label: -100 original text:  health
# token_id: 1337 || attention_mask: 1 || label: -100 original text:  care
# token_id: 1080 || attention_mask: 1 || label: -100 original text:  system
# token_id: 780 || attention_mask: 1 || label: -100 original text:  because
# token_id: 7971 || attention_mask: 1 || label: -100 original text:  immigrants
# token_id: 25129 || attention_mask: 1 || label: -100 original text:  seldom
# token_id: 460 || attention_mask: 1 || label: -100 original text:  can
# token_id: 1414 || attention_mask: 1 || label: -100 original text:  pay
# token_id: 329 || attention_mask: 1 || label: -100 original text:  for
# token_id: 3315 || attention_mask: 1 || label: -100 original text:  medical
# token_id: 2594 || attention_mask: 1 || label: -100 original text:  services
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 11301 || attention_mask: 1 || label: -100 original text:  hospitals
# token_id: 2314 || attention_mask: 1 || label: -100 original text:  cannot
# token_id: 416 || attention_mask: 1 || label: -100 original text:  by
# token_id: 1099 || attention_mask: 1 || label: -100 original text:  law
# token_id: 1210 || attention_mask: 1 || label: -100 original text:  turn
# token_id: 606 || attention_mask: 1 || label: -100 original text:  them
# token_id: 1497 || attention_mask: 1 || label: -100 original text:  away
# token_id: 422 || attention_mask: 1 || label: -100 original text:  from
# token_id: 6334 || attention_mask: 1 || label: -100 original text:  emergency
# token_id: 9519 || attention_mask: 1 || label: -100 original text:  rooms
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 11291 || attention_mask: 1 || label: -100 original text:  Figure
# token_id: 513 || attention_mask: 1 || label: -100 original text:  3
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 19 || attention_mask: 1 || label: -100 original text: 4
# token_id: 14611 || attention_mask: 1 || label: -100 original text:  Political
# token_id: 41140 || attention_mask: 1 || label: -100 original text:  Factors
# token_id: 685 || attention_mask: 1 || label: -100 original text:  [
# token_id: 5159 || attention_mask: 1 || label: -100 original text: Image
# token_id: 6764 || attention_mask: 1 || label: -100 original text:  description
# token_id: 60 || attention_mask: 1 || label: -100 original text: ]
# token_id: 1041 || attention_mask: 1 || label: -100 original text:  Pro
# token_id: 1930 || attention_mask: 1 || label: -100 original text: pos
# token_id: 874 || attention_mask: 1 || label: -100 original text: als
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 2148 || attention_mask: 1 || label: -100 original text:  provide
# token_id: 1104 || attention_mask: 1 || label: -100 original text:  support
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 5692 || attention_mask: 1 || label: -100 original text:  businesses
# token_id: 389 || attention_mask: 1 || label: -100 original text:  are
# token_id: 1690 || attention_mask: 1 || label: -100 original text:  often
# token_id: 8096 || attention_mask: 1 || label: -100 original text:  featured
# token_id: 1626 || attention_mask: 1 || label: -100 original text:  within
# token_id: 1964 || attention_mask: 1 || label: -100 original text:  political
# token_id: 9964 || attention_mask: 1 || label: -100 original text:  campaigns
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 11214 || attention_mask: 1 || label: -100 original text:  Meanwhile
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 9818 || attention_mask: 1 || label: -100 original text:  farmers
# token_id: 7267 || attention_mask: 1 || label: -100 original text:  argue
# token_id: 326 || attention_mask: 1 || label: -100 original text:  that
# token_id: 257 || attention_mask: 1 || label: -100 original text:  a
# token_id: 36040 || attention_mask: 1 || label: -100 original text:  tightening
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 6272 || attention_mask: 1 || label: -100 original text:  immigration
# token_id: 2450 || attention_mask: 1 || label: -100 original text:  policy
# token_id: 561 || attention_mask: 1 || label: -100 original text:  would
# token_id: 307 || attention_mask: 1 || label: -100 original text:  be
# token_id: 13568 || attention_mask: 1 || label: -100 original text:  harmful
# token_id: 780 || attention_mask: 1 || label: -100 original text:  because
# token_id: 9818 || attention_mask: 1 || label: -100 original text:  farmers
# token_id: 8814 || attention_mask: 1 || label: -100 original text:  rely
# token_id: 7272 || attention_mask: 1 || label: -100 original text:  heavily
# token_id: 319 || attention_mask: 1 || label: -100 original text:  on
# token_id: 7026 || attention_mask: 1 || label: -100 original text:  cheap
# token_id: 4827 || attention_mask: 1 || label: -100 original text:  labor
# token_id: 2810 || attention_mask: 1 || label: -100 original text:  provided
# token_id: 416 || attention_mask: 1 || label: -100 original text:  by
# token_id: 5293 || attention_mask: 1 || label: -100 original text:  illegal
# token_id: 7971 || attention_mask: 1 || label: -100 original text:  immigrants
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 554 || attention_mask: 1 || label: -100 original text:  In
# token_id: 1948 || attention_mask: 1 || label: -100 original text:  particular
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 611 || attention_mask: 1 || label: -100 original text:  if
# token_id: 9818 || attention_mask: 1 || label: -100 original text:  farmers
# token_id: 547 || attention_mask: 1 || label: -100 original text:  were
# token_id: 4137 || attention_mask: 1 || label: -100 original text:  forced
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 1873 || attention_mask: 1 || label: -100 original text:  employ
# token_id: 691 || attention_mask: 1 || label: -100 original text:  only
# token_id: 2742 || attention_mask: 1 || label: -100 original text:  legal
# token_id: 3259 || attention_mask: 1 || label: -100 original text:  workers
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 428 || attention_mask: 1 || label: -100 original text:  this
# token_id: 561 || attention_mask: 1 || label: -100 original text:  would
# token_id: 13788 || attention_mask: 1 || label: -100 original text:  substantially
# token_id: 2620 || attention_mask: 1 || label: -100 original text:  increase
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 1575 || attention_mask: 1 || label: -100 original text:  cost
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 13701 || attention_mask: 1 || label: -100 original text:  vegetables
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 26078 || attention_mask: 1 || label: -100 original text:  Restaurant
# token_id: 14659 || attention_mask: 1 || label: -100 original text:  chains
# token_id: 884 || attention_mask: 1 || label: -100 original text:  such
# token_id: 355 || attention_mask: 1 || label: -100 original text:  as
# token_id: 38923 || attention_mask: 1 || label: -100 original text:  Subway
# token_id: 561 || attention_mask: 1 || label: -100 original text:  would
# token_id: 788 || attention_mask: 1 || label: -100 original text:  then
# token_id: 1414 || attention_mask: 1 || label: -100 original text:  pay
# token_id: 2440 || attention_mask: 1 || label: -100 original text:  higher
# token_id: 4536 || attention_mask: 1 || label: -100 original text:  prices
# token_id: 329 || attention_mask: 1 || label: -100 original text:  for
# token_id: 39406 || attention_mask: 1 || label: -100 original text:  lettuce
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 23972 || attention_mask: 1 || label: -100 original text:  tomatoes
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 584 || attention_mask: 1 || label: -100 original text:  other
# token_id: 42531 || attention_mask: 1 || label: -100 original text:  perish
# token_id: 2977 || attention_mask: 1 || label: -100 original text: ables
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 38923 || attention_mask: 1 || label: -100 original text:  Subway
# token_id: 561 || attention_mask: 1 || label: -100 original text:  would
# token_id: 788 || attention_mask: 1 || label: -100 original text:  then
# token_id: 423 || attention_mask: 1 || label: -100 original text:  have
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 5409 || attention_mask: 1 || label: -100 original text:  decide
# token_id: 1771 || attention_mask: 1 || label: -100 original text:  whether
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 17565 || attention_mask: 1 || label: -100 original text:  absorb
# token_id: 777 || attention_mask: 1 || label: -100 original text:  these
# token_id: 3484 || attention_mask: 1 || label: -100 original text:  costs
# token_id: 393 || attention_mask: 1 || label: -100 original text:  or
# token_id: 1208 || attention_mask: 1 || label: -100 original text:  pass
# token_id: 606 || attention_mask: 1 || label: -100 original text:  them
# token_id: 1863 || attention_mask: 1 || label: -100 original text:  along
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 4297 || attention_mask: 1 || label: -100 original text:  customers
# token_id: 416 || attention_mask: 1 || label: -100 original text:  by
# token_id: 11642 || attention_mask: 1 || label: -100 original text:  charging
# token_id: 517 || attention_mask: 1 || label: -100 original text:  more
# token_id: 329 || attention_mask: 1 || label: -100 original text:  for
# token_id: 6352 || attention_mask: 1 || label: -100 original text:  subs
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 14674 || attention_mask: 1 || label: -100 original text:  Overall
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 597 || attention_mask: 1 || label: -100 original text:  any
# token_id: 2458 || attention_mask: 1 || label: -100 original text:  changes
# token_id: 287 || attention_mask: 1 || label: -100 original text:  in
# token_id: 6272 || attention_mask: 1 || label: -100 original text:  immigration
# token_id: 2450 || attention_mask: 1 || label: -100 original text:  policy
# token_id: 481 || attention_mask: 1 || label: -100 original text:  will
# token_id: 423 || attention_mask: 1 || label: -100 original text:  have
# token_id: 10939 || attention_mask: 1 || label: -100 original text:  implications
# token_id: 329 || attention_mask: 1 || label: -100 original text:  for
# token_id: 11301 || attention_mask: 1 || label: -100 original text:  hospitals
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 9818 || attention_mask: 1 || label: -100 original text:  farmers
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 10808 || attention_mask: 1 || label: -100 original text:  restaurants
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 867 || attention_mask: 1 || label: -100 original text:  many
# token_id: 584 || attention_mask: 1 || label: -100 original text:  other
# token_id: 5745 || attention_mask: 1 || label: -100 original text:  organizations
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 412 || attention_mask: 1 || label: -100 original text:  E
# token_id: 1148 || attention_mask: 1 || label: -100 original text:  Is
# token_id: 329 || attention_mask: 1 || label: -100 original text:  for
# token_id: 564 || attention_mask: 1 || label: -100 original text:  �
# token_id: 250 || attention_mask: 1 || label: -100 original text: �
# token_id: 48307 || attention_mask: 1 || label: -100 original text: Economic
# token_id: 447 || attention_mask: 1 || label: -100 original text: �
# token_id: 251 || attention_mask: 1 || label: -100 original text: �
# token_id: 383 || attention_mask: 1 || label: -100 original text:  The
# token_id: 3034 || attention_mask: 1 || label: -100 original text:  economic
# token_id: 10618 || attention_mask: 1 || label: -100 original text:  segment
# token_id: 10399 || attention_mask: 1 || label: -100 original text:  centers
# token_id: 319 || attention_mask: 1 || label: -100 original text:  on
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 3034 || attention_mask: 1 || label: -100 original text:  economic
# token_id: 3403 || attention_mask: 1 || label: -100 original text:  conditions
# token_id: 1626 || attention_mask: 1 || label: -100 original text:  within
# token_id: 543 || attention_mask: 1 || label: -100 original text:  which
# token_id: 5745 || attention_mask: 1 || label: -100 original text:  organizations
# token_id: 8076 || attention_mask: 1 || label: -100 original text:  operate
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 632 || attention_mask: 1 || label: -100 original text:  It
# token_id: 3407 || attention_mask: 1 || label: -100 original text:  includes
# token_id: 4847 || attention_mask: 1 || label: -100 original text:  elements
# token_id: 884 || attention_mask: 1 || label: -100 original text:  such
# token_id: 355 || attention_mask: 1 || label: -100 original text:  as
# token_id: 1393 || attention_mask: 1 || label: -100 original text:  interest
# token_id: 3965 || attention_mask: 1 || label: -100 original text:  rates
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 10610 || attention_mask: 1 || label: -100 original text:  inflation
# token_id: 3965 || attention_mask: 1 || label: -100 original text:  rates
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 10319 || attention_mask: 1 || label: -100 original text:  gross
# token_id: 5928 || attention_mask: 1 || label: -100 original text:  domestic
# token_id: 1720 || attention_mask: 1 || label: -100 original text:  product
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 10681 || attention_mask: 1 || label: -100 original text:  unemployment
# token_id: 3965 || attention_mask: 1 || label: -100 original text:  rates
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 2974 || attention_mask: 1 || label: -100 original text:  levels
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 32445 || attention_mask: 1 || label: -100 original text:  disposable
# token_id: 3739 || attention_mask: 1 || label: -100 original text:  income
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 2276 || attention_mask: 1 || label: -100 original text:  general
# token_id: 3349 || attention_mask: 1 || label: -100 original text:  growth
# token_id: 393 || attention_mask: 1 || label: -100 original text:  or
# token_id: 7794 || attention_mask: 1 || label: -100 original text:  decline
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 3773 || attention_mask: 1 || label: -100 original text:  economy
# token_id: 357 || attention_mask: 1 || label: -100 original text:  (
# token_id: 11291 || attention_mask: 1 || label: -100 original text:  Figure
# token_id: 513 || attention_mask: 1 || label: -100 original text:  3
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 20 || attention_mask: 1 || label: -100 original text: 5
# token_id: 564 || attention_mask: 1 || label: -100 original text:  �
# token_id: 250 || attention_mask: 1 || label: -100 original text: �
# token_id: 48307 || attention_mask: 1 || label: -100 original text: Economic
# token_id: 41140 || attention_mask: 1 || label: -100 original text:  Factors
# token_id: 447 || attention_mask: 1 || label: -100 original text: �
# token_id: 251 || attention_mask: 1 || label: -100 original text: �
# token_id: 6739 || attention_mask: 1 || label: -100 original text:  ).
# token_id: 383 || attention_mask: 1 || label: -100 original text:  The
# token_id: 3034 || attention_mask: 1 || label: -100 original text:  economic
# token_id: 4902 || attention_mask: 1 || label: -100 original text:  crisis
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 2739 || attention_mask: 1 || label: -100 original text:  late
# token_id: 4751 || attention_mask: 1 || label: -100 original text:  2000
# token_id: 82 || attention_mask: 1 || label: -100 original text: s
# token_id: 468 || attention_mask: 1 || label: -100 original text:  has
# token_id: 550 || attention_mask: 1 || label: -100 original text:  had
# token_id: 257 || attention_mask: 1 || label: -100 original text:  a
# token_id: 12465 || attention_mask: 1 || label: -100 original text:  tremendous
# token_id: 4633 || attention_mask: 1 || label: -100 original text:  negative
# token_id: 1245 || attention_mask: 1 || label: -100 original text:  effect
# token_id: 319 || attention_mask: 1 || label: -100 original text:  on
# token_id: 257 || attention_mask: 1 || label: -100 original text:  a
# token_id: 5909 || attention_mask: 1 || label: -100 original text:  vast
# token_id: 7177 || attention_mask: 1 || label: -100 original text:  array
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 5745 || attention_mask: 1 || label: -100 original text:  organizations
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 17658 || attention_mask: 1 || label: -100 original text:  Rising
# token_id: 10681 || attention_mask: 1 || label: -100 original text:  unemployment
# token_id: 30170 || attention_mask: 1 || label: -100 original text:  discouraged
# token_id: 7008 || attention_mask: 1 || label: -100 original text:  consumers
# token_id: 422 || attention_mask: 1 || label: -100 original text:  from
# token_id: 14080 || attention_mask: 1 || label: -100 original text:  purchasing
# token_id: 5789 || attention_mask: 1 || label: -100 original text:  expensive
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 1729 || attention_mask: 1 || label: -100 original text:  non
# token_id: 31195 || attention_mask: 1 || label: -100 original text: essential
# token_id: 7017 || attention_mask: 1 || label: -100 original text:  goods
# token_id: 884 || attention_mask: 1 || label: -100 original text:  such
# token_id: 355 || attention_mask: 1 || label: -100 original text:  as
# token_id: 44820 || attention_mask: 1 || label: -100 original text:  automobiles
# token_id: 290 || attention_mask: 1 || label: -100 original text:  and
# token_id: 5581 || attention_mask: 1 || label: -100 original text:  television
# token_id: 5621 || attention_mask: 1 || label: -100 original text:  sets
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 5018 || attention_mask: 1 || label: -100 original text:  Bank
# token_id: 15536 || attention_mask: 1 || label: -100 original text:  failures
# token_id: 1141 || attention_mask: 1 || label: -100 original text:  during
# token_id: 262 || attention_mask: 1 || label: -100 original text:  the
# token_id: 3034 || attention_mask: 1 || label: -100 original text:  economic
# token_id: 4902 || attention_mask: 1 || label: -100 original text:  crisis
# token_id: 2957 || attention_mask: 1 || label: -100 original text:  led
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 257 || attention_mask: 1 || label: -100 original text:  a
# token_id: 10092 || attention_mask: 1 || label: -100 original text:  dramatic
# token_id: 36040 || attention_mask: 1 || label: -100 original text:  tightening
# token_id: 286 || attention_mask: 1 || label: -100 original text:  of
# token_id: 3884 || attention_mask: 1 || label: -100 original text:  credit
# token_id: 5939 || attention_mask: 1 || label: -100 original text:  markets
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 770 || attention_mask: 1 || label: -100 original text:  This
# token_id: 11829 || attention_mask: 1 || label: -100 original text:  dealt
# token_id: 257 || attention_mask: 1 || label: -100 original text:  a
# token_id: 3236 || attention_mask: 1 || label: -100 original text:  huge
# token_id: 6611 || attention_mask: 1 || label: -100 original text:  blow
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 1363 || attention_mask: 1 || label: -100 original text:  home
# token_id: 31606 || attention_mask: 1 || label: -100 original text:  builders
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 329 || attention_mask: 1 || label: -100 original text:  for
# token_id: 1672 || attention_mask: 1 || label: -100 original text:  example
# token_id: 11 || attention_mask: 1 || label: -100 original text: ,
# token_id: 508 || attention_mask: 1 || label: -100 original text:  who
# token_id: 2497 || attention_mask: 1 || label: -100 original text:  saw
# token_id: 3512 || attention_mask: 1 || label: -100 original text:  demand
# token_id: 329 || attention_mask: 1 || label: -100 original text:  for
# token_id: 649 || attention_mask: 1 || label: -100 original text:  new
# token_id: 7777 || attention_mask: 1 || label: -100 original text:  houses
# token_id: 28940 || attention_mask: 1 || label: -100 original text:  plummet
# token_id: 780 || attention_mask: 1 || label: -100 original text:  because
# token_id: 30401 || attention_mask: 1 || label: -100 original text:  mortgages
# token_id: 547 || attention_mask: 1 || label: -100 original text:  were
# token_id: 4457 || attention_mask: 1 || label: -100 original text:  extremely
# token_id: 2408 || attention_mask: 1 || label: -100 original text:  difficult
# token_id: 284 || attention_mask: 1 || label: -100 original text:  to
# token_id: 7330 || attention_mask: 1 || label: -100 original text:  obtain
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# token_id: 11291 || attention_mask: 1 || label: -100 original text:  Figure
# token_id: 513 || attention_mask: 1 || label: -100 original text:  3
# token_id: 13 || attention_mask: 1 || label: -100 original text: .
# ...
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]
# token_id: 50295 || attention_mask: 0 || label: -100 original text: [PAD]

# %% [markdown]
# # model training

# %%
load_saved_model = False
# load_saved_model = True

if load_saved_model:
    model = torch.load("model.pt")
    model.eval()

else:
    model = AutoModelForCausalLM.from_pretrained(model_name, trust_remote_code=True).cuda()
    model.train()

    for param in model.parameters():
        param.requires_grad = False
    for param in model.layers[-11:].parameters():
        param.requires_grad = True

    get_trainable_params(model)

    trainer:transformers.Trainer = transformers.Trainer(
        model=model, 
        train_dataset=train_dataset,
        args=transformers.TrainingArguments(
            per_device_train_batch_size=1, 
            gradient_accumulation_steps=1,
            warmup_steps=30, 
            max_steps=0, 
            num_train_epochs=2,
            learning_rate=1e-5, 
            fp16=True,
            logging_steps=10, 
            output_dir='outputs',
            report_to="none",
            lr_scheduler_type="constant",
            save_strategy="no",
            evaluation_strategy="epoch"
        ),
        eval_dataset=val_dataset,
        data_collator=transformers.DataCollatorForLanguageModeling(tokenizer, mlm=False)
    )
    
    trainer.train()
    model.eval()
    torch.save(model, "model.pt")


model:transformers.PreTrainedModel
# Out:
# trainable params: 608454656 || all params: 1418270720 || trainable%: 42.90116459571273
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin c:\ProgramData\Anaconda3\lib\site-packages\bitsandbytes\libbitsandbytes_cuda118.dll
# CUDA SETUP: CUDA runtime path found: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.8\bin\cudart64_110.dll
# CUDA SETUP: Highest compute capability among GPUs detected: 8.6
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary c:\ProgramData\Anaconda3\lib\site-packages\bitsandbytes\libbitsandbytes_cuda118.dll...
# c:\ProgramData\Anaconda3\lib\site-packages\bitsandbytes\cuda_setup\main.py:152: UserWarning: C:\ProgramData\Anaconda3 did not contain ['cudart64_110.dll', 'cudart64_120.dll'] as expected! Searching further paths...
#   warn(msg)
# c:\ProgramData\Anaconda3\lib\site-packages\bitsandbytes\cuda_setup\main.py:152: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {WindowsPath('C:/ProgramData/Anaconda3/Library/usr/bin'), WindowsPath('C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA/v11.2/libnvvp'), WindowsPath('C:/Program Files/NVIDIA/CUDNN/v8.x'), WindowsPath('C:/Program Files/NVIDIA GPU Computing Toolkit/CUDA/v11.2/bin'), WindowsPath('E:/texlive/2022/bin/win32'), WindowsPath('C:/Users/Timothe/.dotnet/tools')}
#   warn(msg)
#   0%|          | 0/1288 [00:00<?, ?it/s]
# You're using a CodeGenTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# {'loss': 2.5438, 'learning_rate': 1e-05, 'epoch': 0.02}
# {'loss': 2.4443, 'learning_rate': 1e-05, 'epoch': 0.03}
# {'loss': 2.2723, 'learning_rate': 1e-05, 'epoch': 0.05}
# {'loss': 2.4036, 'learning_rate': 1e-05, 'epoch': 0.06}
# {'loss': 2.2514, 'learning_rate': 1e-05, 'epoch': 0.08}
# {'loss': 2.5326, 'learning_rate': 1e-05, 'epoch': 0.09}
# {'loss': 2.404, 'learning_rate': 1e-05, 'epoch': 0.11}
# {'loss': 2.3788, 'learning_rate': 1e-05, 'epoch': 0.12}
# {'loss': 2.3714, 'learning_rate': 1e-05, 'epoch': 0.14}
# {'loss': 2.2638, 'learning_rate': 1e-05, 'epoch': 0.16}
# {'loss': 2.156, 'learning_rate': 1e-05, 'epoch': 0.17}
# {'loss': 2.4223, 'learning_rate': 1e-05, 'epoch': 0.19}
# {'loss': 2.1931, 'learning_rate': 1e-05, 'epoch': 0.2}
# {'loss': 2.1037, 'learning_rate': 1e-05, 'epoch': 0.22}
# {'loss': 2.3846, 'learning_rate': 1e-05, 'epoch': 0.23}
# {'loss': 2.3, 'learning_rate': 1e-05, 'epoch': 0.25}
# {'loss': 2.2947, 'learning_rate': 1e-05, 'epoch': 0.26}
# {'loss': 2.3094, 'learning_rate': 1e-05, 'epoch': 0.28}
# {'loss': 2.3439, 'learning_rate': 1e-05, 'epoch': 0.3}
# {'loss': 2.3299, 'learning_rate': 1e-05, 'epoch': 0.31}
# {'loss': 2.1814, 'learning_rate': 1e-05, 'epoch': 0.33}
# {'loss': 2.5139, 'learning_rate': 1e-05, 'epoch': 0.34}
# {'loss': 2.2933, 'learning_rate': 1e-05, 'epoch': 0.36}
# {'loss': 2.3322, 'learning_rate': 1e-05, 'epoch': 0.37}
# {'loss': 2.3655, 'learning_rate': 1e-05, 'epoch': 0.39}
# {'loss': 2.2809, 'learning_rate': 1e-05, 'epoch': 0.4}
# {'loss': 2.1778, 'learning_rate': 1e-05, 'epoch': 0.42}
# {'loss': 2.2608, 'learning_rate': 1e-05, 'epoch': 0.43}
# {'loss': 2.1643, 'learning_rate': 1e-05, 'epoch': 0.45}
# {'loss': 2.5109, 'learning_rate': 1e-05, 'epoch': 0.47}
# {'loss': 2.2537, 'learning_rate': 1e-05, 'epoch': 0.48}
# {'loss': 2.3762, 'learning_rate': 1e-05, 'epoch': 0.5}
# {'loss': 2.4844, 'learning_rate': 1e-05, 'epoch': 0.51}
# {'loss': 2.2327, 'learning_rate': 1e-05, 'epoch': 0.53}
# {'loss': 2.3787, 'learning_rate': 1e-05, 'epoch': 0.54}
# {'loss': 2.2177, 'learning_rate': 1e-05, 'epoch': 0.56}
# {'loss': 2.0991, 'learning_rate': 1e-05, 'epoch': 0.57}
# {'loss': 2.3399, 'learning_rate': 1e-05, 'epoch': 0.59}
# {'loss': 2.3467, 'learning_rate': 1e-05, 'epoch': 0.61}
# {'loss': 2.3453, 'learning_rate': 1e-05, 'epoch': 0.62}
# {'loss': 2.1695, 'learning_rate': 1e-05, 'epoch': 0.64}
# {'loss': 2.2696, 'learning_rate': 1e-05, 'epoch': 0.65}
# {'loss': 2.2294, 'learning_rate': 1e-05, 'epoch': 0.67}
# {'loss': 2.2449, 'learning_rate': 1e-05, 'epoch': 0.68}
# {'loss': 2.5002, 'learning_rate': 1e-05, 'epoch': 0.7}
# {'loss': 2.3196, 'learning_rate': 1e-05, 'epoch': 0.71}
# {'loss': 2.2235, 'learning_rate': 1e-05, 'epoch': 0.73}
# {'loss': 2.2003, 'learning_rate': 1e-05, 'epoch': 0.75}
# {'loss': 2.2875, 'learning_rate': 1e-05, 'epoch': 0.76}
# {'loss': 2.1776, 'learning_rate': 1e-05, 'epoch': 0.78}
# {'loss': 2.2167, 'learning_rate': 1e-05, 'epoch': 0.79}
# {'loss': 2.4367, 'learning_rate': 1e-05, 'epoch': 0.81}
# {'loss': 2.3094, 'learning_rate': 1e-05, 'epoch': 0.82}
# {'loss': 2.4927, 'learning_rate': 1e-05, 'epoch': 0.84}
# {'loss': 2.241, 'learning_rate': 1e-05, 'epoch': 0.85}
# {'loss': 2.1046, 'learning_rate': 1e-05, 'epoch': 0.87}
# {'loss': 2.2906, 'learning_rate': 1e-05, 'epoch': 0.89}
# {'loss': 2.3229, 'learning_rate': 1e-05, 'epoch': 0.9}
# {'loss': 2.2614, 'learning_rate': 1e-05, 'epoch': 0.92}
# {'loss': 2.1646, 'learning_rate': 1e-05, 'epoch': 0.93}
# {'loss': 2.4636, 'learning_rate': 1e-05, 'epoch': 0.95}
# {'loss': 2.4278, 'learning_rate': 1e-05, 'epoch': 0.96}
# {'loss': 2.2402, 'learning_rate': 1e-05, 'epoch': 0.98}
# {'loss': 2.3536, 'learning_rate': 1e-05, 'epoch': 0.99}
#   0%|          | 0/21 [00:00<?, ?it/s]
# {'eval_loss': 2.2807137966156006, 'eval_runtime': 129.0679, 'eval_samples_per_second': 1.255, 'eval_steps_per_second': 0.163, 'epoch': 1.0}
# {'loss': 2.103, 'learning_rate': 1e-05, 'epoch': 1.01}
# {'loss': 2.0404, 'learning_rate': 1e-05, 'epoch': 1.02}
# {'loss': 2.0909, 'learning_rate': 1e-05, 'epoch': 1.04}
# {'loss': 2.1279, 'learning_rate': 1e-05, 'epoch': 1.06}
# {'loss': 2.0235, 'learning_rate': 1e-05, 'epoch': 1.07}
# {'loss': 1.9387, 'learning_rate': 1e-05, 'epoch': 1.09}
# {'loss': 2.0016, 'learning_rate': 1e-05, 'epoch': 1.1}
# {'loss': 2.0385, 'learning_rate': 1e-05, 'epoch': 1.12}
# {'loss': 2.1281, 'learning_rate': 1e-05, 'epoch': 1.13}
# {'loss': 2.0417, 'learning_rate': 1e-05, 'epoch': 1.15}
# {'loss': 1.9699, 'learning_rate': 1e-05, 'epoch': 1.16}
# {'loss': 2.0572, 'learning_rate': 1e-05, 'epoch': 1.18}
# {'loss': 2.0917, 'learning_rate': 1e-05, 'epoch': 1.2}
# {'loss': 2.1962, 'learning_rate': 1e-05, 'epoch': 1.21}
# {'loss': 1.9323, 'learning_rate': 1e-05, 'epoch': 1.23}
# {'loss': 1.9052, 'learning_rate': 1e-05, 'epoch': 1.24}
# {'loss': 2.1161, 'learning_rate': 1e-05, 'epoch': 1.26}
# {'loss': 1.8001, 'learning_rate': 1e-05, 'epoch': 1.27}
# {'loss': 2.0702, 'learning_rate': 1e-05, 'epoch': 1.29}
# {'loss': 1.9188, 'learning_rate': 1e-05, 'epoch': 1.3}
# {'loss': 1.8501, 'learning_rate': 1e-05, 'epoch': 1.32}
# {'loss': 2.0122, 'learning_rate': 1e-05, 'epoch': 1.34}
# {'loss': 1.9797, 'learning_rate': 1e-05, 'epoch': 1.35}
# {'loss': 2.0558, 'learning_rate': 1e-05, 'epoch': 1.37}
# {'loss': 2.0583, 'learning_rate': 1e-05, 'epoch': 1.38}
# {'loss': 2.0009, 'learning_rate': 1e-05, 'epoch': 1.4}
# {'loss': 1.7963, 'learning_rate': 1e-05, 'epoch': 1.41}
# {'loss': 2.0423, 'learning_rate': 1e-05, 'epoch': 1.43}
# {'loss': 1.9579, 'learning_rate': 1e-05, 'epoch': 1.44}
# {'loss': 2.077, 'learning_rate': 1e-05, 'epoch': 1.46}
# {'loss': 2.0248, 'learning_rate': 1e-05, 'epoch': 1.48}
# {'loss': 2.0081, 'learning_rate': 1e-05, 'epoch': 1.49}
# {'loss': 1.9466, 'learning_rate': 1e-05, 'epoch': 1.51}
# {'loss': 2.0109, 'learning_rate': 1e-05, 'epoch': 1.52}
# {'loss': 2.0955, 'learning_rate': 1e-05, 'epoch': 1.54}
# {'loss': 1.8796, 'learning_rate': 1e-05, 'epoch': 1.55}
# {'loss': 2.0258, 'learning_rate': 1e-05, 'epoch': 1.57}
# {'loss': 2.0004, 'learning_rate': 1e-05, 'epoch': 1.58}
# {'loss': 1.832, 'learning_rate': 1e-05, 'epoch': 1.6}
# {'loss': 1.8536, 'learning_rate': 1e-05, 'epoch': 1.61}
# {'loss': 2.0152, 'learning_rate': 1e-05, 'epoch': 1.63}
# {'loss': 1.8714, 'learning_rate': 1e-05, 'epoch': 1.65}
# {'loss': 1.9865, 'learning_rate': 1e-05, 'epoch': 1.66}
# {'loss': 1.9223, 'learning_rate': 1e-05, 'epoch': 1.68}
# {'loss': 1.9899, 'learning_rate': 1e-05, 'epoch': 1.69}
# {'loss': 1.9536, 'learning_rate': 1e-05, 'epoch': 1.71}
# {'loss': 1.8365, 'learning_rate': 1e-05, 'epoch': 1.72}
# {'loss': 2.0856, 'learning_rate': 1e-05, 'epoch': 1.74}
# {'loss': 1.9877, 'learning_rate': 1e-05, 'epoch': 1.75}
# {'loss': 1.7657, 'learning_rate': 1e-05, 'epoch': 1.77}
# {'loss': 1.9408, 'learning_rate': 1e-05, 'epoch': 1.79}
# {'loss': 2.0843, 'learning_rate': 1e-05, 'epoch': 1.8}
# {'loss': 2.0148, 'learning_rate': 1e-05, 'epoch': 1.82}
# {'loss': 1.9148, 'learning_rate': 1e-05, 'epoch': 1.83}
# {'loss': 1.9807, 'learning_rate': 1e-05, 'epoch': 1.85}
# {'loss': 1.943, 'learning_rate': 1e-05, 'epoch': 1.86}
# {'loss': 1.8584, 'learning_rate': 1e-05, 'epoch': 1.88}
# {'loss': 1.9133, 'learning_rate': 1e-05, 'epoch': 1.89}
# {'loss': 1.915, 'learning_rate': 1e-05, 'epoch': 1.91}
# {'loss': 1.8072, 'learning_rate': 1e-05, 'epoch': 1.93}
# {'loss': 2.056, 'learning_rate': 1e-05, 'epoch': 1.94}
# {'loss': 2.014, 'learning_rate': 1e-05, 'epoch': 1.96}
# {'loss': 2.0186, 'learning_rate': 1e-05, 'epoch': 1.97}
# {'loss': 1.9741, 'learning_rate': 1e-05, 'epoch': 1.99}
#   0%|          | 0/21 [00:00<?, ?it/s]
# {'eval_loss': 2.2500364780426025, 'eval_runtime': 128.9613, 'eval_samples_per_second': 1.256, 'eval_steps_per_second': 0.163, 'epoch': 2.0}
# {'train_runtime': 960.269, 'train_samples_per_second': 1.341, 'train_steps_per_second': 1.341, 'train_loss': 2.145574182457065, 'epoch': 2.0}

# %% [markdown]
# # model testing

# %%
with torch.no_grad():
  # check if the model works
  for id in range(0,5):
    lecture = val_df.iloc[id]['lecture']
    prompt = "###Lecture:\n\n" + lecture[:4500] + "\n\n###Learning Objectives number 1 to 10:\n\n1. Describe"

    example_batch = tokenizer(prompt, return_tensors='pt', return_attention_mask=False, max_length=2048, truncation=True)
    example_batch = {k: v.cuda() for k, v in example_batch.items()}

    with torch.cuda.amp.autocast():
      output_tokens = model.generate(**example_batch, max_new_tokens=60, temperature=1, do_sample=True, top_p=0.95, num_return_sequences=1)

    print('\n\n', tokenizer.decode(output_tokens[0], skip_special_tokens=True), '\n\n')
    for question in val_df.iloc[id]["question_group"].split('\n'):
      print('original:', question)

    print("\n\n\n\n\n")
# Out:
#  ###Lecture:
#
# 11 Key Considerations Regardless of where your open working group may fall on the spectrum of formal to informal, there are certain things to consider doing and places you can look for support. Keep a record Kick off your committee by establishing a shared digital place where agendas, minutes, best practices, and other documents can reside. Avoid documents becoming orphaned in individual emails. Inventory the different ways to communicate with your community at your institution and establish when, how, and what you will communicate out from your group. One approach that has been taken by a number of open working groups is to consider an open way to document and keep a record. At the University of British Columbia, the UBC Wiki (MediaWiki) is used for sharing all agendas, activities, and members in the open. You may want to look at the Open Ed Tech Collaborative apps available via Sandstorm for collaborative editing tools that will allow you to share and edit documents. Find administrative support Booking meetings, finding rooms, sending out agendas, and other administrative tasks can make or break a group’s functionality if not done. Is there a dean or administrator on your committee that is able to offer administrative support? Who is writing announcements? Where are you sending them? Who has booked the room, ordered the coffee? Set up communication and marketing It never hurts to look good! Are there channels at your institution that will offer you marketing and promotional advice? Are there logos and creative designs already available in the open marketplace that can help you with banners and graphics? Are there institutions that can share open marketing ideas? Think about a digital or web presence as early as you can. Check the Open Education Week website or the Open Access Week Graphics for promotional materials. Provide professional development for members Depending on the composition and background of your open working group members, different professional development opportunities will be useful for sustaining the group. Think about training on the different technologies offered to sustain open at your institution. Look at conferences related to open subjects, such as the Open Textbook Summit. Other professional development opportunities may include inter-institutional events, development sprints, and workshops (such as on copyright, Creative Commons licences, and open pedagogy). 12 Engage Different Stakeholders What roles at an institution have a role in open? There are many! By expanding your open working group membership in different areas, you can bring new perspectives into the discussion around open education and create and sustain new partnerships. Do you have membership in your group to get the best uptake for open at your institution? Who should you partner or collaborate with to increase support for and interest in open? Keep the conversations going by identifying and raising open as part of institutional/departmental conversations (e.g., new technology assessments, copyright strategies, teaching and learning support). Faculties. Depending on the size of your institution, different faculties or faculty units may be key drivers and supporters of open educational resources (OER) and open educational practices (OEP). This also can open up questions of what does open education look like and how is it used in different disciplinary contexts. The use of OER is approached very differently in different faculties. Curriculum committees. Articulation committees. BCcampus. Textbook committees. Student unions or groups. Advocate for and develop awareness among students, and support students in their own advocacy efforts. You can assist students in applying for OER grants, work with students around #textbookbroke campaigns, support students in conducting environmental scans, and more. Program council. Cross-institutional committees. Bookstore. Library. As described in more detail below, the library is typically a key stak ...
#
# ###Learning Objectives number 1 to 10:
#
# 1. Describe the nature and function of open education.
# 2. Explain open pedagogy and how it relates to teaching.
# 3. Identify the history of open education and the communities that use OER.
# 4. Describe the social and educational ethics of open education.
# 5. Explain the
#
#
# original: Determine collaboration points and opportunities.
# original: Identify roles at your institution that can help support open education.
# original: Explore processes and aspects of the working group that can be open.
# original: Identify examples of workshops and events that showcase and support open education.
# original: Create an inventory of open resources at your institution.
#
#
#
#
#
#
#
#
#  ###Lecture:
#
# 24 Key Terms and Concepts ABCs of Attitudes: The three components to an attitude are, A=Affect (how we feel about something); B=Behaviour (how we act towards something); and C=Cognition (what we think about something).Attitudes: The positive or negative, long-lasting evaluations we have regarding people and things. Balance theory: Fritz Heider’s Balance Theory is a framework that can predict attitude and behavioural change. In marketing, this framework demonstrates the importance of consistency (balance) within the triad, and how consumers will seek to harmonize their values, beliefs, and perceptions when they experience cognitive inconsistencies. Central route to persuasion: This aspect of the Elaboration Likelihood Model identifies that messages requiring extensive mental processing are more likely to result in long-term attitude changes, especially with an audience who is motivated and highly involved with the subject/topic. Cognitive dissonance: A type of cognitive inconsistency, this term describes the discomfort consumers may feel when their beliefs, values, attitudes, or perceptions are inconsistent or contradictory to their original belief or understanding. Consumers with cognitive dissonance related to a purchasing decision will often seek to resolve this internal turmoil they are experiencing by returning the product or finding a way to justify it and minimizing their sense of buyer’s remorse. Descriptive norms: While norms give us a sense of how we might behave in accordance with society, descriptive norms refer to our perception of how people actually behave. Elaboration likelihood model: This models examines two different ways persuasion can be achieved (central route; peripheral route) depending on how motivated the audience is by the message and how much thinking (mental processing) needs to be done with respect to the contents of the message. Halo effect: When we experience one positive trait about a person we may assume other positive features or traits as well. Match-up hypothesis: The degree to which a source and a brand are objectively perceived as a “good match” because the source’s image and the brand’s position are a good fit and logically aligned. Multi-attribute attitude model: This model provides a framework that can be used to measure consumers’ attitudes towards specific products or services. The model identifies how consumer attitudes are informed by measuring and evaluating the attitudes of a product; the beliefs about those attributes; and the relative importance we give those attributes. Norms: Norms can be considered unspoken rules that members of a society follow because they represent what is good and/or right and they inform us on how we should behave. Peripheral route to persuasion: This aspect of the Elaboration Likelihood Model identifies that messages requiring minimal mental processing result in short-term attitude changes, especially with an audience who is not motivated and has low involvement with the subject/topic. Persuasion: In marketing, persuasion is seen a process of creating messages that will change the beliefs, attitudes, and/or behaviours of a target audience (e.g. consumers). Principle of attitude consistency: This theory comes into effect when there is strong alignment among the ABC’s of attitude: the relationship between what we feel (A), think (C), and how we act (B) are consistent and in close relation to one another. Self-determination theory: This theory examines how our motivations and personality (internalized factors) inform our attitudes and behaviour in the absence of external influences (e.g. subjective norms, which contrasts the theory of planned behaviour). Social norms: Accepted informal group rules and standards that guide our behaviour. Social norms generalize the accepted way of thinking, feeling, and behaving in a way that our groups support. Source: In marketing, the source is often depicted as a spokesperson or representative of a brand or company and  ...
#
# ###Learning Objectives number 1 to 10:
#
# 1. Describe the three components of the attitude A, B, and C; and how consumers will change their attitudes based on social influences.
# Define attitude theory
# Elaboration likelihood model
# Balance theory
# Descriptive and Peripheral route to persuasion
# Persuasion
# Self-determination theory
#
#
#
# original: Define the meaning of “attitudes” and summarize its key features.
# original: Identify strategies used to change attitudes.
# original: Explain the relationship between “involvement” and “attitudes.”
# original: Identify ways in which marketers can use persuasion to form or change consumer attitudes.
#
#
#
#
#
#
#
#
#  ###Lecture:
#
# As we learned in the previous section, stress —especially if it is chronic—takes a toll on our bodies and can have enormously negative health implications. When we experience events in our lives that we appraise as stressful, it is essential that we use effective coping strategies to manage our stress. Coping refers to mental and behavioral efforts that we use to deal with problems relating to stress, including its presumed cause and the unpleasant feelings and emotions it produces. Coping Styles Lazarus and Folkman (1984) distinguished two fundamental kinds of coping: problem-focused coping and emotion-focused coping. In problem-focused coping, one attempts to manage or alter the problem that is causing one to experience stress (i.e., the stressor). Problem-focused coping strategies are similar to strategies used in everyday problem-solving: they typically involve identifying the problem, considering possible solutions, weighing the costs and benefits of these solutions, and then selecting an alternative (Lazarus &amp; Folkman, 1984). As an example, suppose Bradford receives a midterm notice that he is failing statistics class. If Bradford adopts a problem-focused coping approach to managing his stress, he would be proactive in trying to alleviate the source of the stress. He might contact his professor to discuss what must be done to raise his grade, he might also decide to set aside two hours daily to study statistics assignments, and he may seek tutoring assistance. A problem-focused approach to managing stress means we actively try to do things to address the problem. Emotion-focused coping, in contrast, consists of efforts to change or reduce the negative emotions associated with stress. These efforts may include avoiding, minimizing, or distancing oneself from the problem, or positive comparisons with others (“I’m not as bad off as she is”), or seeking something positive in a negative event (“Now that I’ve been fired, I can sleep in for a few days”). In some cases, emotion-focused coping strategies involve reappraisal, whereby the stressor is construed differently (and somewhat self-deceptively) without changing its objective level of threat (Lazarus &amp; Folkman, 1984). For example, a person sentenced to federal prison who thinks, “This will give me a great chance to network with others,” is using reappraisal. If Bradford adopted an emotion-focused approach to managing his midterm deficiency stress, he might watch a comedy movie, play video games, or spend hours on Twitter to take his mind off the situation. In a certain sense, emotion-focused coping can be thought of as treating the symptoms rather than the actual cause. While many stressors elicit both kinds of coping strategies, problem-focused coping is more likely to occur when encountering stressors we perceive as controllable, while emotion-focused coping is more likely to predominate when faced with stressors that we believe we are powerless to change (Folkman &amp; Lazarus, 1980). Clearly, emotion-focused coping is more effective in dealing with uncontrollable stressors. For example, if at midnight you are stressing over a 40-page paper due in the morning that you have not yet started, you are probably better off recognizing the hopelessness of the situation and doing something to take your mind off it; taking a problem-focused approach by trying to accomplish this task would only lead to frustration, anxiety, and even more stress. Fortunately, most stressors we encounter can be modified and are, to varying degrees, controllable. A person who cannot stand her job can quit and look for work elsewhere; a middle-aged divorcee can find another potential partner; the freshman who fails an exam can study harder next time, and a breast lump does not necessarily mean that one is fated to die of breast cancer. Control and Stress The desire and ability to predict events, make decisions, and affect outcomes—that is, to enact control in our lives—is a basic tenet of huma ...
#
# ###Learning Objectives number 1 to 10:
#
# 1. Describe two types of coping and distinguish problem-focused and emotion-focused coping strategies
# 2. Distinguish the costs and benefits of problem-focused and emotion-focused coping
# 3. Describe emotion-focused coping and give examples
# 4. Distinguish emotional coping and reappraisal, giving
#
#
# original: Define coping and differentiate between problem-focused and emotion-focused coping
# original: Describe the importance of perceived control in our reactions to stress
# original: Explain how social support is vital in health and longevity
#
#
#
#
#
#
#
#
#  ###Lecture:
#
# Early theories assumed that personality was expressed in people’s physical appearance. One early approach, developed by the German physician Franz Joseph Gall (1758-1828) and known as phrenology, was based on the idea that we could measure personality by assessing the patterns of bumps on people’s skulls (Figure 12.1, “Phrenology”). In the Victorian age, phrenology was taken seriously and many people promoted its use as a source of psychological insight and self-knowledge. Machines were even developed for helping people analyze skulls (Simpson, 2005). However, because careful scientific research did not validate the predictions of the theory, phrenology has now been discredited in contemporary psychology. Figure 12.1 Phrenology. This definition of phrenology with a chart of the skull appeared in Webster’s Academic Dictionary, circa 1895. [Long Description] Another approach, known as somatology, championed by the psychologist William Herbert Sheldon (1898-1977), was based on the idea that we could determine personality from people’s body types (Figure 12.2, “Sheldon’s Body Types”). Sheldon (1940) argued that people with more body fat and a rounder physique (endomorphs) were more likely to be assertive and bold, whereas thinner people (ectomorphs) were more likely to be introverted and intellectual. As with phrenology, scientific research did not validate the predictions of the theory, and somatology has now been discredited in contemporary psychology. Figure 12.2 Sheldon’s Body Types. William Sheldon erroneously believed that people with different body types had different personalities. Another approach to detecting personality is known as physiognomy, or the idea that it is possible to assess personality from facial characteristics. In contrast to phrenology and somatology, for which no research support has been found, contemporary research has found that people are able to detect some aspects of a person’s character — for instance, whether they are gay or straight and whether they are liberal or conservative — at above-chance levels by looking only at his or her face (Rule &amp; Ambady, 2010; Rule, Ambady, Adams, &amp; Macrae, 2008; Rule, Ambady, &amp; Hallett, 2009). Despite these results, the ability to detect personality from faces is not guaranteed. Olivola and Todorov (2010) recently studied the ability of thousands of people to guess the personality characteristics of hundreds of thousands of faces on the website What’s My Image? ( In contrast to the predictions of physiognomy, the researchers found that these people would have made more accurate judgments about the strangers if they had just guessed, using their expectations about what people in general are like, rather than trying to use the particular facial features of individuals to help them. It seems then that the predictions of physiognomy may also, in the end, find little empirical support. Personality as Traits Personalities are characterized in terms of traits, which are relatively enduring characteristics that influence our behaviour across many situations. Personality traits such as introversion, friendliness, conscientiousness, honesty, and helpfulness are important because they help explain consistencies in behaviour. The most popular way of measuring traits is by administering personality tests on which people self-report about their own characteristics. Psychologists have investigated hundreds of traits using the self-report approach, and this research has found many personality traits that have important implications for behaviour. You can see some examples of the personality dimensions that have been studied by psychologists and their implications for behaviour in Table 12.1, “Some Personality Traits That Predict Behaviour,”. Table 12.1 Some Personality Traits That Predict Behaviour. [Skip Table] Trait Description Examples of behaviours exhibited by people who have the trait Authoritarianism (Adorno, Frenkel-Brunswik, Levinson, &amp; Sanford, 1950) A  ...
#
# ###Learning Objectives number 1 to 10:
#
# 1. Describe phrenology and the controversy surrounding the theory.
# 2. Describe somatology and the controversy surrounding the theory.
# 3. Describe physiognomy and the controversy surrounding the theory.
# 4. Describe some fundamental principles of the nature versus nurture debate.
# 5. Describe
#
#
# original: Outline and critique the early approaches to assessing personality.
# original: Define and review the strengths and limitations of the trait approach to personality.
# original: Summarize the measures that have been used to assess psychological disorders.
#
#
#
#
#
#
#
#
#  ###Lecture:
#
# In this chapter, we will explore the evidence that informs reading research within psycholinguistics. We will look at the neurological disorders associated with reading. These include various types of dyslexia and their specific deficit types have the potential to provide new insights onto the process of normal reading. We will then look at some models of reading and the evidence they use to inform their stages and information processing. 42 8.1 Reading Models Dinesh Ramoo The Logogen Model Proposed by Morton (1969, 1970), the Logogen model assumes units called logogens which are used to understand words that are heard and read. Logogens are specialized recognition units that are used for word recognition. Logogen is from the Greek λόγος (logos, word ) and γένος (genos, origin ). So, every word we know has its own logogen which contains phonemic and graphemic information about that word. As we encounter a word, the logogen for that word accumulates activation until a given threshold is reached upon which the word is recognized. An important issue to remember is that the logogen itself doesn’t contain the word. Rather, it contains information that can be used to retrieve the word. Accessing words is direct and parallel for all words. Each logogen has a resting activation level. As it receives more evidence that corresponds to its word, this activation level increases up to a threshold. For example, if the input contains the grapheme &lt;p&gt;, then all logogens containing that visual input get an increase in activation. Once enough graphemes are there to fully activate the logogen it fires and word recognition occurs. The model is particularly good as including contextual information in recognizing words. One of the problems with this model was that it equated visual and auditory input for a word as using the same logogen process. A prediction of this model would be that a spoken prime should facilitate a written word just as much as a visual prime. However, experimental evidence contradicted this prediction (Winnick &amp; Daniel, 1970). Following his own observation that confirms these findings, Morton divided the model into different sets of logogens (see Figure 8.1). Figure 8.1 Logogen Model While the logogen model is quite successful in explaining word recognition in terms of semantics, there are some limitations to this model. There have been challenges to the existence of the logogen as a unit of recognition. Given that different pathways process information on the way to word recognition, is it really necessary to have such centralized units? The model’s limited scope for word recognition that ignores innate syntactic rules and grammatical construction is also a limitation. Interactive Activation Model McClelland and Rumelhart (1981) and Rumelhart and McClelland (1982) developed the Interactive activation and competition (IAC) model. The model accounted for word context effects. This means that letters are easier to recognize if they are in words rather than as isolated letters (also known as the word superiority effect). As seen in Figure 8.3, the model consists of three levels: visual feature units, indivudla letter units, and word units. Each unit is connected to units in the level immediately before and after it with connections that are excitatory (if appropriate) or inhibitory (if inappropriate). Let’s look at the example in Figure 8.3 for the word leap. First, the individual features are recognized. For example, the vertical line feature excites &lt;E&gt;, &lt;P&gt;, and &lt;L&gt; but combined with the horizontal line feature, it only excites &lt;L&gt;. All the letter units in turn excite words that contain them, but the words that do not contain the letters act as inhibitory signals in the opposite direction. Once enough letter units have accumulated activation of the word &lt;LEAP&gt;, then that word is recognized. The inhibition of units lower down the model if a positive recognition is not made accounts for th ...
#
# ###Learning Objectives number 1 to 10:
#
# 1. Describe the basic features of natural language
# 2. Describe the basic features of the natural language processing approach
# 3. Describe the basic features of the automatic speech recognition technique
# 4. Describe the basic features of the emotion recognition model
# 5. Describe the basic features of the sentiment analysis model
#
#
# original: Describe the various pieces of evidence that is used by researchers of reading.
# original: Evaluate the difference between different types of reading disorders.
# original: Understand the basics of the dual-route and connectionist models of reading.
